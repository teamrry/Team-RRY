# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 

df = pd.read_csv('C:\\Users\\Yaswanth\\Desktop\DSP\\realestate.csv')
df.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS   Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S   Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S   Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB   Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP   Biggin
# 5  Abbotsford    40 Federation La    3.0    h   850000.0     PI   Biggin
# 6  Abbotsford         55a Park St    4.0    h  1600000.0     VB   Nelson
# 7  Abbotsford        16 Maugie St    4.0    h        NaN     SN   Nelson
# 8  Abbotsford        53 Turner St    2.0    h        NaN      S   Biggin
# 9  Abbotsford        99 Turner St    2.0    h        NaN      S  Collins
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0       2.0       1.0  1.0     126.0
# ...

# %%
# for knowing missing values

df.isnull().sum()
# Out:
# Suburb             4
# Address           14
# Rooms             24
# Type              24
# Price           3177
# Method            24
# SellerG           24
# Date              24
# Distance          24
# Postcode          24
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# CouncilArea     3063
# Lattitude       2940
# Longtitude      2939
# dtype: int64

# %%
dfnew = df

# %%
dfnew.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0       3.0       2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt CouncilArea Lattitude Longtitude
# 0           NaN        NaN       Yarra  -37.8014   144.9958
# ...

# %%
from collections import Counter
Counter(df['Suburb'])
# Out:
# Counter({'Abbotsford': 78,
#          'Airport West': 75,
#          'Albert Park': 78,
#          'Alphington': 42,
#          'Altona': 62,
#          'Altona North': 94,
#          'Armadale': 139,
#          'Ascot Vale': 130,
#          'Ashburton': 90,
#          'Ashwood': 82,
#          'Avondale Heights': 88,
#          'Balaclava': 26,
#          'Balwyn': 180,
#          'Balwyn North': 224,
#          '    RE': 20,
#          'Bentleigh': 170,
#          'Bentleigh East': 314,
#          'Box Hill': 71,
#          'Braybrook': 55,
#          'Brighton': 248,
#          'Brighton East': 226,
#          'Brunswick': 228,
#          'Brunswick West': 126,
#          'Bulleen': 91,
#          'Burwood': 135,
#          'Camberwell': 226,
#          'Canterbury': 73,
#          'Carlton North': 52,
#          'Carnegie': 161,
#          'Caulfield': 14,
#          'Caulfield North': 44,
#          'Caulfield South': 64,
#          'Chadstone': 64,
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=14246, step=1),
#  Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#         'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#         'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#         'Longtitude'],
#        dtype='object')]

# %%
# removing unnecessary columns that are not usable now

df1 = dfnew.drop(columns = ['Suburb','Address','SellerG','Date','Postcode','CouncilArea', 'Lattitude',
        'Longtitude'])
df1.head()
# Out:
#    Rooms Type      Price Method  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0    2.0    h        NaN     SS       2.5       2.0       1.0  1.0     126.0
# 1    2.0    h  1480000.0      S       2.5       2.0       1.0  1.0     202.0
# 2    2.0    h  1035000.0      S       2.5       2.0       1.0  0.0     156.0
# 3    3.0    u        NaN     VB       2.5       3.0       2.0  1.0       0.0
# 4    3.0    h  1465000.0     SP       2.5       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt
# 0           NaN        NaN
# 1           NaN        NaN
# 2          79.0     1900.0
# 3           NaN        NaN
# 4         150.0     1900.0

# %%
Counter(df1['Rooms'])
# Out:
# Counter({2.0: 4197,
#          3.0: 5800,
#          4.0: 2707,
#          1.0: 801,
#          5.0: 629,
#          6.0: 60,
#          7.0: 10,
#          8.0: 11,
#          nan: 1,
#          nan: 1,
#          10.0: 3,
#          nan: 1,
#          nan: 1,
#          9.0: 2,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          12.0: 2,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1})

# %%
# assigning values to missing data(i have  taken 3 because most of the indians fell having 3 is enough)
Rooms_null = df1[df1['Rooms'].isnull()].index.tolist()
df1['Rooms'].iloc[Rooms_null]= 3.0
Counter(df1['Rooms'])
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Counter({2.0: 4197,
#          3.0: 5824,
#          4.0: 2707,
#          1.0: 801,
#          5.0: 629,
#          6.0: 60,
#          7.0: 10,
#          8.0: 11,
#          10.0: 3,
#          9.0: 2,
#          12.0: 2})

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type              24
# Price           3177
# Method            24
# Distance          24
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
Counter(df1['Type'])
# Out:
# Counter({'h': 9080, 'u': 3568, 't': 1574, nan: 24})

# %%
Type_null = df1[df1['Type'].isnull()].index.tolist()
df1['Type'].iloc[Type_null] = 'h'
Counter(df1['Type'])
# Out:
# Counter({'h': 9104, 'u': 3568, 't': 1574})

# %%
df1['Price'].median()
# Out:
# 900000.0

# %%
df1['Price'].mean()
# Out:
# 1076960.6711536725

# %%
df1['Price'][df1['Price'].isnull()]= 900000.0
#Counter[dfnew1['Price']] can not use this as the column is numeric
df1.isnull().sum()
# Out:
# <ipython-input-15-675d1bc1c25f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Price'][df1['Price'].isnull()]= 900000.0
# Rooms              0
# Type               0
# Price              0
# Method            24
# Distance          24
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
df1['Price'].mean()
# Out:
# 1037496.6775937105

# %%
df1['Price'].median()
# Out:
# 900000.0

# %%
Counter(df1['Method'])
# Out:
# Counter({'SS': 12,
#          'S': 8406,
#          'VB': 1098,
#          'SP': 2013,
#          'PI': 1883,
#          'SN': 587,
#          'W': 51,
#          'PN': 121,
#          'SA': 51,
#          nan: 24})

# %%
Method_null = df1[df1['Method'].isnull()].index.tolist()
df1['Method'].iloc[Method_null] = 'S'
Counter(df1['Method'])
# Out:
# Counter({'SS': 12,
#          'S': 8430,
#          'VB': 1098,
#          'SP': 2013,
#          'PI': 1883,
#          'SN': 587,
#          'W': 51,
#          'PN': 121,
#          'SA': 51})

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance          24
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
Counter(df1['Distance'])
# Out:
# Counter({2.5: 106,
#          13.5: 180,
#          3.3: 320,
#          6.4: 185,
#          13.8: 234,
#          11.1: 94,
#          6.3: 139,
#          5.9: 256,
#          11.0: 90,
#          12.2: 82,
#          10.5: 175,
#          6.6: 87,
#          9.7: 274,
#          9.2: 665,
#          nan: 1,
#          nan: 1,
#          13.0: 427,
#          13.9: 499,
#          13.1: 71,
#          10.8: 55,
#          11.2: 1136,
#          nan: 1,
#          nan: 1,
#          10.7: 226,
#          5.2: 228,
#          11.8: 240,
#          11.7: 135,
#          nan: 1,
#          nan: 1,
#          7.8: 491,
#          9.0: 102,
#          3.2: 52,
#          11.4: 260,
#          8.9: 37,
#          8.1: 44,
#          9.3: 76,
#          13.6: 91,
#          3.4: 71,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          1.6: 145,
#          10.3: 34,
#          8.5: 79,
#          7.7: 187,
#          8.0: 339,
#          9.4: 94,
# ...

# %%
df['Distance'].mean()
# Out:
# 8.621635494304728

# %%
df['Distance'].median()
# Out:
# 8.8

# %%
df1['Distance'][df1['Distance'].isnull()]= 8.62
Counter(df1['Distance'])
# Out:
# <ipython-input-24-75b80704c83f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Distance'][df1['Distance'].isnull()]= 8.62
# Counter({2.5: 106,
#          13.5: 180,
#          3.3: 320,
#          6.4: 185,
#          13.8: 234,
#          11.1: 94,
#          6.3: 139,
#          5.9: 256,
#          11.0: 90,
#          12.2: 82,
#          10.5: 175,
#          6.6: 87,
#          9.7: 274,
#          9.2: 665,
#          8.62: 24,
#          13.0: 427,
#          13.9: 499,
#          13.1: 71,
#          10.8: 55,
#          11.2: 1136,
#          10.7: 226,
#          5.2: 228,
#          11.8: 240,
#          11.7: 135,
#          7.8: 491,
#          9.0: 102,
#          3.2: 52,
#          11.4: 260,
#          8.9: 37,
#          8.1: 44,
#          9.3: 76,
# ...

# %%
df1['Distance'].mean()
# Out:
# 8.621632739014592

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance           0
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
df1.head(10)
# Out:
#    Rooms Type      Price Method  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0    2.0    h   900000.0     SS       2.5       2.0       1.0  1.0     126.0
# 1    2.0    h  1480000.0      S       2.5       2.0       1.0  1.0     202.0
# 2    2.0    h  1035000.0      S       2.5       2.0       1.0  0.0     156.0
# 3    3.0    u   900000.0     VB       2.5       3.0       2.0  1.0       0.0
# 4    3.0    h  1465000.0     SP       2.5       3.0       2.0  0.0     134.0
# 5    3.0    h   850000.0     PI       2.5       3.0       2.0  1.0      94.0
# 6    4.0    h  1600000.0     VB       2.5       3.0       1.0  2.0     120.0
# 7    4.0    h   900000.0     SN       2.5       3.0       2.0  2.0     400.0
# 8    2.0    h   900000.0      S       2.5       4.0       1.0  2.0     201.0
# 9    2.0    h   900000.0      S       2.5       3.0       2.0  1.0     202.0
#
#    BuildingArea  YearBuilt
# 0           NaN        NaN
# 1           NaN        NaN
# 2          79.0     1900.0
# ...

# %%
Counter(df1['Bedroom2'])
# Out:
# Counter({2.0: 3490,
#          3.0: 4593,
#          4.0: 1930,
#          6.0: 42,
#          nan: 1,
#          nan: 1,
#          1.0: 667,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          5.0: 448,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
# ...

# %%
df1['Bedroom2'].mean()
# Out:
# 2.8405641849669703

# %%
df1['Bedroom2'].median()
# Out:
# 3.0

# %%
df1['Bedroom2'][df1['Bedroom2'].isnull()] = 3
Counter(df1['Bedroom2'])
# Out:
# <ipython-input-31-728b78039c47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Bedroom2'][df1['Bedroom2'].isnull()] = 3
# Counter({2.0: 3490,
#          3.0: 7637,
#          4.0: 1930,
#          6.0: 42,
#          1.0: 667,
#          5.0: 448,
#          7.0: 8,
#          0.0: 13,
#          8.0: 5,
#          9.0: 4,
#          30.0: 1,
#          20.0: 1})

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance           0
# Bedroom2           0
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
df1['Bathroom'].mean()
# Out:
# 1.5308873415461526

# %%
df1['Bathroom'].median()
# Out:
# 1.0

# %%
df1['Bathroom'][df1['Bathroom'].isnull()] = 1.0
Counter(df1['Bathroom'])
# Out:
# <ipython-input-35-533b77d80671>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Bathroom'][df1['Bathroom'].isnull()] = 1.0
# Counter({1.0: 9363,
#          2.0: 3898,
#          3.0: 803,
#          7.0: 3,
#          4.0: 105,
#          0.0: 40,
#          5.0: 28,
#          6.0: 4,
#          12.0: 1,
#          8.0: 1})

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance           0
# Bedroom2           0
# Bathroom           0
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
Counter(df1['Car'])
# Out:
# Counter({1.0: 4924,
#          0.0: 954,
#          2.0: 4307,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          6.0: 30,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          5.0: 41,
#          4.0: 373,
#          nan: 1,
#          3.0: 557,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
# ...

# %%
df1['Car'][df1['Car'].isnull()]= 1
Counter(df1['Car'])
# Out:
# <ipython-input-38-105801d353a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Car'][df1['Car'].isnull()]= 1
# Counter({1.0: 7968,
#          0.0: 954,
#          2.0: 4307,
#          6.0: 30,
#          5.0: 41,
#          4.0: 373,
#          3.0: 557,
#          8.0: 6,
#          7.0: 8,
#          11.0: 1,
#          26.0: 1})

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance           0
# Bedroom2           0
# Bathroom           0
# Car                0
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# dtype: int64

# %%
df1= df1.drop(columns=['YearBuilt'])

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance           0
# Bedroom2           0
# Bathroom           0
# Car                0
# Landsize        3061
# BuildingArea    8078
# dtype: int64

# %%
Counter(df['Landsize'])
# Out:
# Counter({126.0: 12,
#          202.0: 19,
#          156.0: 15,
#          0.0: 2026,
#          134.0: 11,
#          94.0: 11,
#          120.0: 14,
#          400.0: 14,
#          201.0: 11,
#          181.0: 18,
#          245.0: 10,
#          4292.0: 1,
#          230.0: 22,
#          256.0: 8,
#          nan: 1,
#          nan: 1,
#          220.0: 18,
#          nan: 1,
#          176.0: 26,
#          nan: 1,
#          nan: 1,
#          214.0: 15,
#          nan: 1,
#          nan: 1,
#          195.0: 16,
#          238.0: 13,
#          113.0: 11,
#          nan: 1,
#          nan: 1,
#          138.0: 20,
#          183.0: 15,
#          150.0: 12,
#          780.0: 24,
#          119.0: 13,
#          4290.0: 1,
#          124.0: 10,
#          147.0: 16,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          166.0: 20,
#          98.0: 8,
#          nan: 1,
#          nan: 1,
#          168.0: 17,
#          162.0: 18,
#          nan: 1,
# ...

# %%
df1['Landsize'].mean()
# Out:
# 469.1814036656236

# %%
df1['Landsize'].median()
# Out:
# 351.0

# %%
df1['Landsize'][df1['Landsize'].isnull()] = 351.0
Counter(df1['Landsize'])
# Out:
# <ipython-input-45-95254c14a665>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Landsize'][df1['Landsize'].isnull()] = 351.0
# Counter({126.0: 12,
#          202.0: 19,
#          156.0: 15,
#          0.0: 2026,
#          134.0: 11,
#          94.0: 11,
#          120.0: 14,
#          400.0: 14,
#          201.0: 11,
#          181.0: 18,
#          245.0: 10,
#          4292.0: 1,
#          230.0: 22,
#          256.0: 8,
#          351.0: 3072,
#          220.0: 18,
#          176.0: 26,
#          214.0: 15,
#          195.0: 16,
#          238.0: 13,
#          113.0: 11,
#          138.0: 20,
#          183.0: 15,
#          150.0: 12,
#          780.0: 24,
#          119.0: 13,
#          4290.0: 1,
#          124.0: 10,
#          147.0: 16,
#          166.0: 20,
# ...

# %%
df1.isnull().sum()
# Out:
# Rooms              0
# Type               0
# Price              0
# Method             0
# Distance           0
# Bedroom2           0
# Bathroom           0
# Car                0
# Landsize           0
# BuildingArea    8078
# dtype: int64

# %%
Counter(df['BuildingArea'])
# Out:
# Counter({nan: 1,
#          nan: 1,
#          79.0: 32,
#          nan: 1,
#          150.0: 60,
#          nan: 1,
#          142.0: 30,
#          220.0: 23,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          210.0: 12,
#          82.0: 26,
#          147.0: 27,
#          107.0: 44,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          75.0: 52,
#          nan: 1,
#          80.0: 64,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          190.0: 21,
#          94.0: 45,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          97.0: 39,
#          129.0: 37,
#          110.0: 70,
#          nan: 1,
#          nan: 1,
#          105.0: 50,
#          nan: 1,
#          73.0: 34,
#          135.0: 44,
#          167.0: 23,
#          nan: 1,
#          27.0: 2,
#          60.0: 33,
#          85.0: 64,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          174.0: 21,
# ...

# %%
df1['BuildingArea'].mean()
# Out:
# 146.86153858625164

# %%
df1['BuildingArea'].median()
# Out:
# 125.0

# %%
df1['BuildingArea'][df1['BuildingArea'].isnull()] = 125.0
Counter(df1['BuildingArea'])
# Out:
# <ipython-input-50-7e6b25366d52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['BuildingArea'][df1['BuildingArea'].isnull()] = 125.0
# Counter({125.0: 8129,
#          79.0: 32,
#          150.0: 60,
#          142.0: 30,
#          220.0: 23,
#          210.0: 12,
#          82.0: 26,
#          147.0: 27,
#          107.0: 44,
#          75.0: 52,
#          80.0: 64,
#          190.0: 21,
#          94.0: 45,
#          97.0: 39,
#          129.0: 37,
#          110.0: 70,
#          105.0: 50,
#          73.0: 34,
#          135.0: 44,
#          167.0: 23,
#          27.0: 2,
#          60.0: 33,
#          85.0: 64,
#          174.0: 21,
#          50.0: 28,
#          128.0: 28,
#          18.0: 6,
#          124.0: 25,
#          91.0: 21,
#          81.0: 31,
# ...

# %%
df1.isnull().sum()
# Out:
# Rooms           0
# Type            0
# Price           0
# Method          0
# Distance        0
# Bedroom2        0
# Bathroom        0
# Car             0
# Landsize        0
# BuildingArea    0
# dtype: int64

# %%
df1.describe()
# Out:
#               Rooms         Price      Distance      Bedroom2      Bathroom  \
# count  14246.000000  1.424600e+04  14246.000000  14246.000000  14246.000000
# mean       2.894146  1.037497e+06      8.621633      2.874631      1.417451
# std        0.984983  5.863217e+05      3.556326      0.901077      0.672293
# min        1.000000  8.500000e+04      1.200000      0.000000      0.000000
# 25%        2.000000  7.070000e+05      5.900000      2.000000      1.000000
# 50%        3.000000  9.000000e+05      8.800000      3.000000      1.000000
# 75%        3.000000  1.200000e+06     11.200000      3.000000      2.000000
# max       12.000000  8.000000e+06     15.000000     30.000000     12.000000
#
#                 Car      Landsize  BuildingArea
# count  14246.000000  14246.000000  14246.000000
# mean       1.422926    443.788081    134.465251
# std        0.879184   1042.684109     89.657173
# min        0.000000      0.000000      0.000000
# ...

# %%
df1.cov()
# Out:
#                       Rooms         Price       Distance       Bedroom2  \
# Rooms              0.970191  2.684555e+05       0.979707       0.697223
# Price         268455.484648  3.437731e+11 -120108.026030  199794.128268
# Distance           0.979707 -1.201080e+05      12.647452       0.787816
# Bedroom2           0.697223  1.997941e+05       0.787816       0.811940
# Bathroom           0.317340  1.414551e+05       0.120032       0.323732
# Car                0.290823  1.080719e+05       0.692402       0.278227
# Landsize          64.788868  3.617246e+07     123.465796      62.540647
# BuildingArea      25.644762  1.200366e+07      22.906439      24.397471
#
#                    Bathroom            Car      Landsize  BuildingArea
# Rooms              0.317340       0.290823  6.478887e+01  2.564476e+01
# Price         141455.091776  108071.864268  3.617246e+07  1.200366e+07
# Distance           0.120032       0.692402  1.234658e+02  2.290644e+01
# ...

# %%
dfcv1 = df['Rooms'].cov(df['Price'])
print(dfcv1)
# Out:
# 353816.758576153

# %%
dfcv2 = df['Distance'].cov(df['Price'])
print(dfcv2)
# Out:
# -173688.09137474827

# %%
dfcv3 = df['Bedroom2'].cov(df['Price'])
print(dfcv3)
# Out:
# 335329.9769107131

# %%
dfcv4 = df['Bathroom'].cov(df['Price'])
print(dfcv4)
# Out:
# 232612.43657112375

# %%
dfcv5 = df['Car'].cov(df['Price'])
dfcv5
# Out:
# 174130.77458005186

# %%
dfcv6 = df['Landsize'].cov(df['Price'])
dfcv6
# Out:
# 58757781.41019682

# %%
dfcv7 = df['BuildingArea'].cov(df['Price'])
dfcv7
# Out:
# 36304137.644854404

# %%
df1.corr()
# Out:
#                  Rooms     Price  Distance  Bedroom2  Bathroom       Car  \
# Rooms         1.000000  0.464844  0.279683  0.785563  0.479224  0.335831
# Price         0.464844  1.000000 -0.057602  0.378168  0.358859  0.209651
# Distance      0.279683 -0.057602  1.000000  0.245845  0.050204  0.221451
# Bedroom2      0.785563  0.378168  0.245845  1.000000  0.534399  0.351203
# Bathroom      0.479224  0.358859  0.050204  0.534399  1.000000  0.375409
# Car           0.335831  0.209651  0.221451  0.351203  0.375409  1.000000
# Landsize      0.063084  0.059168  0.033296  0.066565  0.064563  0.099470
# BuildingArea  0.290392  0.228346  0.071841  0.301994  0.301544  0.191453
#
#               Landsize  BuildingArea
# Rooms         0.063084      0.290392
# Price         0.059168      0.228346
# Distance      0.033296      0.071841
# Bedroom2      0.066565      0.301994
# Bathroom      0.064563      0.301544
# Car           0.099470      0.191453
# Landsize      1.000000      0.045754
# ...

# %%
dfcr1 = df['Rooms'].corr(df['Price'])
dfcr1
# Out:
# 0.5563742309956955

# %%
dfcr2 = df['Distance'].corr(df['Price'])
dfcr2
# Out:
# -0.07316699119518949

# %%
dfcr3 = df['Bedroom2'].corr(df['Price'])
dfcr3
# Out:
# 0.5322091264685291

# %%
dfcr4 = df['Bathroom'].corr(df['Price'])
dfcr4
# Out:
# 0.5159750737591619

# %%
dfcr5 = df['Car'].corr(df['Price'])
dfcr5
# Out:
# 0.28750544588391586

# %%
dfcr6 = df['Landsize'].corr(df['Price'])
dfcr6
# Out:
# 0.07144334609772388

# %%
dfcr7 = df['BuildingArea'].corr(df['Price'])
dfcr7
# Out:
# 0.3610642116948052

# %%
df1['Rooms'].plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1[df1['Price']>900000].sample(200).plot.scatter(x='Rooms',y='Bedroom2')
# Out:
# <AxesSubplot:xlabel='Rooms', ylabel='Bedroom2'>

# %%
df1['Price'].median()
# Out:
# 900000.0

# %%
df1[df1['Price']<900000].sample(200).plot.scatter(x='Rooms',y='Bedroom2')
# Out:
# <AxesSubplot:xlabel='Rooms', ylabel='Bedroom2'>

# %%
df1.describe()
# Out:
#               Rooms         Price      Distance      Bedroom2      Bathroom  \
# count  14246.000000  1.424600e+04  14246.000000  14246.000000  14246.000000
# mean       2.894146  1.037497e+06      8.621633      2.874631      1.417451
# std        0.984983  5.863217e+05      3.556326      0.901077      0.672293
# min        1.000000  8.500000e+04      1.200000      0.000000      0.000000
# 25%        2.000000  7.070000e+05      5.900000      2.000000      1.000000
# 50%        3.000000  9.000000e+05      8.800000      3.000000      1.000000
# 75%        3.000000  1.200000e+06     11.200000      3.000000      2.000000
# max       12.000000  8.000000e+06     15.000000     30.000000     12.000000
#
#                 Car      Landsize  BuildingArea
# count  14246.000000  14246.000000  14246.000000
# mean       1.422926    443.788081    134.465251
# std        0.879184   1042.684109     89.657173
# min        0.000000      0.000000      0.000000
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.distplot(df['Price'], color = 'g')
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Rooms'],color = 'g')
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rooms', ylabel='Density'>

# %%
sns.distplot(df['Bedroom2'],color = 'g')
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Bedroom2', ylabel='Density'>

# %%
plt.figure(figsize=(12, 8))

df2 = df1.loc[:,['Rooms','Bedroom2','Landsize','Price']]
print(df2.head())

vg_corr = df2.corr()
sns.heatmap(vg_corr, 
            xticklabels = vg_corr.columns.values,
            yticklabels = vg_corr.columns.values,
            annot = True);
# Out:
#    Rooms  Bedroom2  Landsize      Price
# 0    2.0       2.0     126.0   900000.0
# 1    2.0       2.0     202.0  1480000.0
# 2    2.0       2.0     156.0  1035000.0
# 3    3.0       3.0       0.0   900000.0
# 4    3.0       3.0     134.0  1465000.0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
# %whos
# Out:
# Variable             Type         Data/Info
# -------------------------------------------
# Counter              type         <class 'collections.Counter'>
# LogisticRegression   type         <class 'sklearn.linear_mo<...>stic.LogisticRegression'>
# Method_null          list         n=24
# Rooms_null           list         n=24
# Type_null            list         n=24
# cross_val_score      function     <function cross_val_score at 0x00000226AE3C60D0>
# df                   DataFrame               Suburb        <...>[14246 rows x 19 columns]
# df1                  DataFrame           Rooms Type      Pr<...>[14246 rows x 10 columns]
# df2                  DataFrame           Rooms  Bedroom2  L<...>n[14246 rows x 4 columns]
# dfcr1                float64      0.5563742309956955
# dfcr2                float64      -0.07316699119518949
# dfcr3                float64      0.5322091264685291
# dfcr4                float64      0.5159750737591619
# ...

# %%
df1.head()
# Out:
#    Rooms Type      Price Method  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0    2.0    h   900000.0     SS       2.5       2.0       1.0  1.0     126.0
# 1    2.0    h  1480000.0      S       2.5       2.0       1.0  1.0     202.0
# 2    2.0    h  1035000.0      S       2.5       2.0       1.0  0.0     156.0
# 3    3.0    u   900000.0     VB       2.5       3.0       2.0  1.0       0.0
# 4    3.0    h  1465000.0     SP       2.5       3.0       2.0  0.0     134.0
#
#    BuildingArea
# 0         125.0
# 1         125.0
# 2          79.0
# 3         125.0
# 4         150.0

# %% [markdown]
# # Saperating input and output variable

# %%
dfinput = df1.loc[:,['Rooms','Type','Method','Distance','Bedroom2','Bathroom','Car','Landsize','BuildingArea']]
dfinput.head()
# Out:
#    Rooms Type Method  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0    2.0    h     SS       2.5       2.0       1.0  1.0     126.0
# 1    2.0    h      S       2.5       2.0       1.0  1.0     202.0
# 2    2.0    h      S       2.5       2.0       1.0  0.0     156.0
# 3    3.0    u     VB       2.5       3.0       2.0  1.0       0.0
# 4    3.0    h     SP       2.5       3.0       2.0  0.0     134.0
#
#    BuildingArea
# 0         125.0
# 1         125.0
# 2          79.0
# 3         125.0
# 4         150.0

# %%
dfoutput = df1.loc[:,['Price']]
dfoutput.head()
# Out:
#        Price
# 0   900000.0
# 1  1480000.0
# 2  1035000.0
# 3   900000.0
# 4  1465000.0

# %% [markdown]
# # Spliting data into 80:20

# %%
split = int(.8*len(df1))
print(split)
# Out:
# 11396

# %%
df1.shape
# Out:
# (14246, 10)

# %%
14246*.8
# Out:
# 11396.800000000001

# %%
14246*.2
# Out:
# 2849.2000000000003

# %%
rename??
# Out:
# Object `rename` not found.

# %%
# %whos
# Out:
# Variable             Type         Data/Info
# -------------------------------------------
# Counter              type         <class 'collections.Counter'>
# LogisticRegression   type         <class 'sklearn.linear_mo<...>stic.LogisticRegression'>
# Method_null          list         n=24
# Rooms_null           list         n=24
# Type_null            list         n=24
# cross_val_score      function     <function cross_val_score at 0x00000226AE3C60D0>
# df                   DataFrame               Suburb        <...>[14246 rows x 19 columns]
# df1                  DataFrame           Rooms Type      Pr<...>[14246 rows x 10 columns]
# df2                  DataFrame           Rooms  Bedroom2  L<...>n[14246 rows x 4 columns]
# dfcr1                float64      0.5563742309956955
# dfcr2                float64      -0.07316699119518949
# dfcr3                float64      0.5322091264685291
# dfcr4                float64      0.5159750737591619
# ...

# %%
dfinput.isnull().sum()
# Out:
# Rooms           0
# Type            0
# Method          0
# Distance        0
# Bedroom2        0
# Bathroom        0
# Car             0
# Landsize        0
# BuildingArea    0
# dtype: int64

# %%
(dfinput['Landsize'] == 0).sum() ## there are 2026 '0' values in landsize
# Out:
# 2026

# %%
dfinput['Landsize'].shape
# Out:
# (14246,)

# %%
import statsmodels.api as sm 
import statsmodels.formula.api as smf

# %%
# ordilary least Square
ols = smf.ols('Price~Rooms+Bedroom2+Bathroom',data = df1).fit()
print(ols)
print(ols.summary())
# Out:
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     1505.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:29:16   Log-Likelihood:            -2.0746e+05
# No. Observations:               14246   AIC:                         4.149e+05
# Df Residuals:                   14242   BIC:                         4.150e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.825e+05   1.47e+04     12.400      0.000    1.54e+05    2.11e+05
# ...

# %%
ols = smf.ols('Price~Rooms+Bedroom2+Bathroom+Landsize+BuildingArea',data = df1).fit()
print(ols)
print(ols.summary())
# Out:
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.246
# Method:                 Least Squares   F-statistic:                     930.7
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:31:04   Log-Likelihood:            -2.0741e+05
# No. Observations:               14246   AIC:                         4.148e+05
# Df Residuals:                   14240   BIC:                         4.149e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1.618e+05   1.48e+04     10.924      0.000    1.33e+05    1.91e+05
# ...

# %%
df2 = df1.corr()
print(df2)
# Out:
#                  Rooms     Price  Distance  Bedroom2  Bathroom       Car  \
# Rooms         1.000000  0.464844  0.279683  0.785563  0.479224  0.335831
# Price         0.464844  1.000000 -0.057602  0.378168  0.358859  0.209651
# Distance      0.279683 -0.057602  1.000000  0.245845  0.050204  0.221451
# Bedroom2      0.785563  0.378168  0.245845  1.000000  0.534399  0.351203
# Bathroom      0.479224  0.358859  0.050204  0.534399  1.000000  0.375409
# Car           0.335831  0.209651  0.221451  0.351203  0.375409  1.000000
# Landsize      0.063084  0.059168  0.033296  0.066565  0.064563  0.099470
# BuildingArea  0.290392  0.228346  0.071841  0.301994  0.301544  0.191453
#
#               Landsize  BuildingArea
# Rooms         0.063084      0.290392
# Price         0.059168      0.228346
# Distance      0.033296      0.071841
# Bedroom2      0.066565      0.301994
# Bathroom      0.064563      0.301544
# Car           0.099470      0.191453
# Landsize      1.000000      0.045754
# ...

# %%
x=df2.loc['Price']
print(x)
# Out:
# Rooms           0.464844
# Price           1.000000
# Distance       -0.057602
# Bedroom2        0.378168
# Bathroom        0.358859
# Car             0.209651
# Landsize        0.059168
# BuildingArea    0.228346
# Name: Price, dtype: float64

# %%
x = df2[df2.loc['Price']>.5]
print(x)
# Out:
#           Rooms  Price  Distance  Bedroom2  Bathroom       Car  Landsize  \
# Price  0.464844    1.0 -0.057602  0.378168  0.358859  0.209651  0.059168
#
#        BuildingArea
# Price      0.228346

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=14246, step=1),
#  Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#         'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#         'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#         'Longtitude'],
#        dtype='object')]

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0       3.0       2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt CouncilArea Lattitude Longtitude
# 0           NaN        NaN       Yarra  -37.8014   144.9958
# ...

# %%
df1['Postcode'] = df['Postcode']

# %%
df1.head()
# Out:
#    Rooms Type      Price Method  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0    2.0    h   900000.0     SS       2.5       2.0       1.0  1.0     126.0
# 1    2.0    h  1480000.0      S       2.5       2.0       1.0  1.0     202.0
# 2    2.0    h  1035000.0      S       2.5       2.0       1.0  0.0     156.0
# 3    3.0    u   900000.0     VB       2.5       3.0       2.0  1.0       0.0
# 4    3.0    h  1465000.0     SP       2.5       3.0       2.0  0.0     134.0
#
#    BuildingArea  Postcode
# 0         125.0    3067.0
# 1         125.0    3067.0
# 2          79.0    3067.0
# 3         125.0    3067.0
# 4         150.0    3067.0

# %%
df1.isnull().sum()
# Out:
# Rooms            0
# Type             0
# Price            0
# Method           0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Postcode        24
# dtype: int64

# %%
df1.shape
# Out:
# (14246, 11)

# %%
df1['Postcode'].plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1['Postcode'].median()
# Out:
# 3085.0

# %%
df1['Postcode'].mean()
# Out:
# 3098.212065813528

# %%
df1['Postcode'].iloc[df1['Postcode'].isnull()] = 3085.0
df1.isnull().sum()
# Out:
# C:\Users\Yaswanth\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Rooms           0
# Type            0
# Price           0
# Method          0
# Distance        0
# Bedroom2        0
# Bathroom        0
# Car             0
# Landsize        0
# BuildingArea    0
# Postcode        0
# dtype: int64

# %%
df1.shape
# Out:
# (14246, 11)

# %%
corr_df1 = df1.corr()

# %%
ols1 = smf.ols('Price~Rooms+Postcode+Bedroom2+Bathroom',data = df1).fit()
print(ols1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     1400.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:51:16   Log-Likelihood:            -2.0706e+05
# No. Observations:               14246   AIC:                         4.141e+05
# Df Residuals:                   14241   BIC:                         4.142e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.066e+06   2.18e+05    -27.792      0.000   -6.49e+06   -5.64e+06
# ...

# %%
ols2=smf.ols('Price~Rooms+Bathroom+Bedroom2+Car',data = df1).fit()
print(ols2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:52:43   Log-Likelihood:            -2.0746e+05
# No. Observations:               14246   AIC:                         4.149e+05
# Df Residuals:                   14241   BIC:                         4.150e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.782e+05   1.48e+04     12.036      0.000    1.49e+05    2.07e+05
# ...

# %%
ols3=smf.ols('Price~Rooms+Bathroom+Bedroom2+Car+Postcode',data = df1).fit()
print(ols3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     1124.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:53:33   Log-Likelihood:            -2.0705e+05
# No. Observations:               14246   AIC:                         4.141e+05
# Df Residuals:                   14240   BIC:                         4.142e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.101e+06   2.18e+05    -27.939      0.000   -6.53e+06   -5.67e+06
# ...

# %%
df1['Postcode'].cov(df1['Price'])
# Out:
# 7926106.476152095

# %%
df1.axes
# Out:
# [RangeIndex(start=0, stop=14246, step=1),
#  Index(['Rooms', 'Type', 'Price', 'Method', 'Distance', 'Bedroom2', 'Bathroom',
#         'Car', 'Landsize', 'BuildingArea', 'Postcode'],
#        dtype='object')]

# %%
ols4 = smf.ols('Price~Rooms+Distance+Bathroom+Bedroom2+Car',data = df1).fit()
print(ols4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     1083.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:58:28   Log-Likelihood:            -2.0713e+05
# No. Observations:               14246   AIC:                         4.143e+05
# Df Residuals:                   14240   BIC:                         4.143e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.549e+05    1.6e+04     22.201      0.000    3.24e+05    3.86e+05
# ...

# %%
ols5 = smf.ols('Price~Rooms+Distance+Bathroom+Bedroom2+Car+Postcode',data = df1).fit()
print(ols5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     1148.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:            -2.0661e+05
# No. Observations:               14246   AIC:                         4.132e+05
# Df Residuals:                   14239   BIC:                         4.133e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.568e+06   2.12e+05    -30.943      0.000   -6.98e+06   -6.15e+06
# ...

# %%
ols6 = smf.ols('Price~Rooms+Distance+Bathroom+Bedroom2+Car+Postcode+Landsize',data = df1).fit()
print(ols6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     986.8
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        12:00:44   Log-Likelihood:            -2.0661e+05
# No. Observations:               14246   AIC:                         4.132e+05
# Df Residuals:                   14238   BIC:                         4.133e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.569e+06   2.12e+05    -30.957      0.000   -6.98e+06   -6.15e+06
# ...

# %%
ols7 = smf.ols('Price~Rooms+Distance+Bathroom+BuildingArea+Car+Postcode+Landsize',data = df1).fit()
print(ols7.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     1005.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        12:02:03   Log-Likelihood:            -2.0656e+05
# No. Observations:               14246   AIC:                         4.131e+05
# Df Residuals:                   14238   BIC:                         4.132e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -6.554e+06   2.11e+05    -31.060      0.000   -6.97e+06   -6.14e+06
# ...

# %%
df1.axes
# Out:
# [RangeIndex(start=0, stop=14246, step=1),
#  Index(['Rooms', 'Type', 'Price', 'Method', 'Distance', 'Bedroom2', 'Bathroom',
#         'Car', 'Landsize', 'BuildingArea', 'Postcode'],
#        dtype='object')]

# %%
ols8 = smf.ols('Price~Rooms+Distance+Bathroom+BuildingArea+Car+Postcode+Landsize+Method',data = df1).fit()
print(ols8.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     500.4
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        12:04:53   Log-Likelihood:            -2.0641e+05
# No. Observations:               14246   AIC:                         4.128e+05
# Df Residuals:                   14230   BIC:                         4.130e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -6.493e+06    2.1e+05    -30.905      0.000    -6.9e+06   -6.08e+06
# ...

# %%
ols9 = smf.ols('Price~Rooms+Distance+Bathroom+BuildingArea+Car+Postcode+Landsize+Type',data = df1).fit()
print(ols9.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.375
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     948.8
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        12:06:36   Log-Likelihood:            -2.0608e+05
# No. Observations:               14246   AIC:                         4.122e+05
# Df Residuals:                   14236   BIC:                         4.122e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -6.95e+06   2.05e+05    -33.978      0.000   -7.35e+06   -6.55e+06
# ...

# %%
corr_df1['Price']
# Out:
# Rooms           0.464844
# Price           1.000000
# Distance       -0.057602
# Bedroom2        0.378168
# Bathroom        0.358859
# Car             0.209651
# Landsize        0.059168
# BuildingArea    0.228346
# Postcode        0.227092
# Name: Price, dtype: float64

# %%
import statsmodels.graphics.api as smg
corr_matrix = np.corrcoef(df1)
smg.plot_corr(corr_matrix, xnames=df1.columns)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-34f59de274a5> in <module>
#       1 import statsmodels.graphics.api as smg
# ----> 2 corr_matrix = np.corrcoef(df1)
#       3 smg.plot_corr(corr_matrix, xnames=df1.columns)
#       4 plt.show()
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2549         warnings.warn('bias and ddof have no effect and are deprecated',
#    2550                       DeprecationWarning, stacklevel=3)
# -> 2551     c = cov(x, y, rowvar)
#    2552     try:
#    2553         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2454             w *= aweights
#    2455
# ...
